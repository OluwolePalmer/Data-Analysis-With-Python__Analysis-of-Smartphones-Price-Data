# %% [markdown]
# TASKS:
#
# - Identify all the brands of smartphones present in the data.
# - Identify the top 10 brands with most smartphones. Also, visualize this result.
# - For each brand, determine the count, average price, lowest price, highest price of smartphones using groupby.
# - Using get_group, show details of the brand with the most smartphones.
#
# See the data source file for information about the dataset.

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('smartphones.csv')
df
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
#Identify all the brands of smartphones present in the data.
print('There are',len(df['Brand'].unique()),'brands of smartphones in the data, and they are the following:\n\n',df['Brand'].unique())
# Out:
# There are 37 brands of smartphones in the data, and they are the following:
#
#  ['Realme' 'Samsung' 'Motorola' 'Xiaomi' 'Nothing' 'POCO' 'Apple' 'OPPO'
#  'Alcatel' 'Vivo' 'ZTE' 'OnePlus' 'TCL' 'CAT' 'SPC' 'Cubot' 'Google'
#  'Ulefone' 'Nokia' 'Honor' 'Huawei' 'Sony' 'Hammer' 'Qubo' 'Blackview'
#  'Asus' 'Microsoft' 'BQ' 'Crosscall' 'Doro' 'Fairphone' 'Funker' 'Gigaset'
#  'LG' 'Maxcom' 'Swissvoice' 'Lenovo']

# %%
# Identify the top 10 brands with most smartphones.
df['Brand'].value_counts().head(10).to_frame()
# Out:
#           count
# Brand
# Samsung     458
# Xiaomi      351
# Apple       292
# Realme      117
# OPPO         92
# POCO         67
# Motorola     57
# Huawei       57
# TCL          36
# Cubot        34

# %%
# Top 10 brands visualization.
df['Brand'].value_counts().head(10).plot(kind='bar', color='pink')
plt.plot(df['Brand'].value_counts().head(10), color='black', marker='o')
plt.title('Top 10 Smartphone Brands')
plt.ylabel('count')
plt.ylim(0,)
# Out:
# (0.0, 480.9)

# %%
# For each brand, determine the count, average price, lowest price, highest price of smartphones using groupby.
df.groupby('Brand', as_index=False).agg({'Smartphone':'count', 'Final Price':['min', 'max', 'mean']})
# Out:
#          Brand Smartphone Final Price
#                     count         min      max        mean
# 0      Alcatel          7       70.98   226.98  113.842857
# 1        Apple        292      109.00  2119.00  842.396815
# 2         Asus          3      444.72  1021.00  751.573333
# 3           BQ          1      140.76   140.76  140.760000
# 4    Blackview         27      109.32   490.24  215.399259
# 5          CAT          6      116.99   588.99  378.208333
# 6    Crosscall          7      299.00   699.00  497.754286
# 7        Cubot         34       84.95   299.00  179.586765
# 8         Doro          3      179.47   291.88  254.410000
# 9    Fairphone          1      634.19   634.19  634.190000
# 10      Funker          1      220.78   220.78  220.780000
# 11     Gigaset          3      186.65   294.89  252.346667
# 12      Google          9      187.40  1166.96  516.978889
# 13      Hammer         21      160.51   539.68  242.617143
# ...

# %%
# Using get_group, show details of the brand with the most smartphones.
df.groupby('Brand').get_group('Samsung')
# Out:
#                                              Smartphone    Brand  \
# 1              Samsung Galaxy M23 5G 4/128GB Azul Libre  Samsung
# 8             Samsung Galaxy M23 5G 4/128GB Verde Libre  Samsung
# 18                Samsung Galaxy M13 4/64GB Verde Libre  Samsung
# 28           Samsung Galaxy M53 5G 8/128GB Marrón Libre  Samsung
# 38             Samsung Galaxy M33 5G 6/128GB Azul Libre  Samsung
# ...                                                 ...      ...
# 1790      Samsung Galaxy Z Flip3 5G 8/128GB Verde Libre  Samsung
# 1791  Samsung Galaxy Z Fold3 5G 256GB Negro + Funda ...  Samsung
# 1792  Samsung Galaxy Z Fold3 5G 512GB Negro + Funda ...  Samsung
# 1793  Samsung Galaxy Z Fold4 12/256GB Beige Libre + ...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
#
#                Model   RAM  Storage  Color Free  Final Price
# 1         Galaxy M23   4.0    128.0   Blue  Yes       279.00
# 8         Galaxy M23   4.0    128.0  Green  Yes       279.00
# ...
